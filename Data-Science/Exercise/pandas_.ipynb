# %%
import pandas as pd

s = pd.Series([1, 2, 3, 4], name='A')
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: A, dtype: int64

# %%
index = [i for i in range(1, 5)]
s1 = pd.Series(index, index=index, name='A')
# s2 = pd.Series(index, )
s1

# %%
s2 = pd.Series(index)
print(s2)

# %%
result = s2 * 2
result

# %%
filter_result = s2[s2 > 2]
filter_result

# %%
s2 > 2

# %%
print(type(s2>2))

# %%
import numpy as np

r = pd.Series([1, 2, 3, 4])
r

# %%
print(r.sum())
print(r.mean())
print(r.max())
print(r.min())
print(r.std())
print(r.var())

# %%
a = [11, 22, 33]
s = pd.Series(a)
print(s)

# %%
index = s.index
print(index)

# %%
values = s.values
values

# %%
stats = s.describe()
print(type(stats))
stats

# %%
max_index = s.idxmax()
min_index = s.idxmin()
print(type(min_index))
print(min_index)
print(max_index)

# %%
print(s.dtype)
print(s.shape)
print(s.size)
print(s.head())
print(s.tail())

# %%
data = [['Alice', 18, 160], ['Max', 22, 175], ['Apple', 16, 180]]
df = pd.DataFrame(data, columns=['Name', 'Age', 'Height'])
# print(df)
# print(df.dtypes)
df

# %%
dic = {'Name': ['Alice', 'Max', 'Apple'], 'Age': [18, 22, 16], 'Height': [160, 175, 180]}
df2 = pd.DataFrame(dic)
df2

# %%
import numpy as np
nd = np.array(data)
df3 = pd.DataFrame(nd, columns=['Name', 'Age', 'Height'])
df3

# %%
data1 = [['Alice', 18, 160], ['Max', 22, 175], ['Apple', 16]]
df4 = pd.DataFrame(data1, columns=['Name', 'Age', 'Height'])
df4

# %%
dic = {
    'calories': [420, 380, 390],
    'duration': [50, 40, 30]
}
df = pd.DataFrame(dic)
df

# %%
print(df.loc[1])
print(type(df.loc[1]))

# %%
print(df.loc[[0, 1]])

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['NY', 'LA', 'Chicago', 'Houston']
}

df = pd.DataFrame(data)
df

# %%
print(df.head(2))

# %%
print(df.tail(2))

# %%
df.info()

# %%
df.describe()

# %%
df_sorted = df.sort_values(by='Age', ascending=False)
df_sorted

# %%
df[['Name', 'Age']]

# %%
df.iloc[1:3]

# %%
df.loc[1:3]

# %%
df.groupby('City')['Age'].mean()

# %%
print(df.groupby('City')['Age'])

# %%
df['Age'] = df['Age'].fillna(30)

# %%
df.to_csv('output.csv')

# %%
df.loc[1:3]
