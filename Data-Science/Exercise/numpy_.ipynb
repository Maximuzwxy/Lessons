# %%
import numpy as np
from numpy import random as nr

nr.seed(12)
# r = nr.randint(1, 10, size=(4, 5))
r = nr.randint(1, 10, size=(2, 5))
r
# Out:
# array([[7, 2, 3, 4, 4],
#        [1, 7, 2, 5, 6]])

# %%
np.sum(r)
# Out:
# np.int64(92)

# %%
np.average(r)

# %%
np.var(r)

# %%
np.mean(r)

# %%
d = np.arange(1, 6)
d

# %%
np.average(d)

# %%
np.mean(d)

# %%
np.var(d)

# %%
np.std(d)

# %%
r

# %%
a = np.array([[3, 2, 4], [8, 7, 1], [9, 6, 5]])
a

# %%
data = np.sort(a, axis=0)
data

# %%
np.sort(a, axis=0)

# %%
np.arange(1, 10, 2)

# %%
np.linspace(2, 10, 5)

# %%
np.linspace(0, 9, 10).reshape(2, 5)

# %%
np.linspace(0, 9, 6).reshape(2, 3)

# %%
np.logspace(0, 9, 6, base=np.e).reshape(2, 3)

# %%
np.logspace(0, 3, 5)
